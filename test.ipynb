# %%
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "e:\ML Projects\Autogen-AgentAI\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ASUS\AppData\Local\Temp\ipykernel_20532\3047370094.py", line 1, in <module>
#     import transformers
#   File "e:\ML Projects\Autogen-AgentAI\venv\lib\site-packages\transformers\__init__.py", line 26, in <module>
#     from . import dependency_versions_check
#   File "e:\ML Projects\Autogen-AgentAI\venv\lib\site-packages\transformers\dependency_versions_check.py", line 16, in <module>
#     from .utils.versions import require_version, require_version_core
#   File "e:\ML Projects\Autogen-AgentAI\venv\lib\site-packages\transformers\utils\__init__.py", line 27, in <module>
# ...
